# %%
pip install langchain langchain-openai langchain-community langchain-text-splitters chromadb pypdf python-dotenv
# Out:
# Requirement already satisfied: langchain in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (1.2.12)
# Requirement already satisfied: langchain-openai in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (1.1.11)
# Requirement already satisfied: langchain-community in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (0.4.1)
# Requirement already satisfied: langchain-text-splitters in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (1.1.1)
# Requirement already satisfied: chromadb in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (1.5.5)
# Requirement already satisfied: pypdf in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (6.9.1)
# Requirement already satisfied: python-dotenv in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain) (1.2.19)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.20)
# Requirement already satisfied: packaging>=23.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (4.12.1)
# Requirement already satisfied: certifi in /opt/homebrew/opt/certifi/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.1->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-openai) (2.29.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.2.28)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from langchain-community) (2.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: build>=1.0.3 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.42.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: pyproject_hooks in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/homebrew/opt/rpds-py/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from tokenizers>=0.13.2->chromadb) (1.7.1)
# Requirement already satisfied: filelock>=3.10.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.4.2)
# Requirement already satisfied: click>=8.2.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.6/libexec/lib/python3.14/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Verify installation
import sys
print(f"Python version: {sys.version}")

# Verify key packages are installed
try:
    import langchain
    import langchain_core
    print(f"✅ LangChain version: {langchain.__version__}")
    print("✅ All core packages installed successfully!")
except ImportError as e:
    print(f"⚠️  Error: {e}")
    print("Please ensure all packages are installed correctly.")
# Out:
# Python version: 3.14.3 (main, Feb  3 2026, 15:32:20) [Clang 17.0.0 (clang-1700.6.3.2)]
# ✅ LangChain version: 1.2.12
# ✅ All core packages installed successfully!

# %%
# Standard library imports
import os
from pathlib import Path
from dotenv import load_dotenv

# LangChain core imports
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.document_loaders import PyPDFLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate

# Modern LangChain agent imports (latest pattern from LangChain docs)
from langchain.agents import create_agent
from langchain.tools import tool

# Load environment variables - check current directory first, then parent
current_dir = Path.cwd()
env_path = current_dir / '.env'
if env_path.exists():
    load_dotenv(env_path)
    print(f"✅ Loading .env from: {env_path}")
else:
    # Try parent directory
    parent_env = current_dir.parent / '.env'
    if parent_env.exists():
        load_dotenv(parent_env)
        print(f"✅ Loading .env from: {parent_env}")
    else:
        # Fallback to default behavior (searches current and parent directories)
        load_dotenv()
        print("⚠️  No .env file found. Using default load_dotenv() search")

# Verify API key is set
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    print("⚠️  WARNING: OPENAI_API_KEY not found in environment variables!")
    print("Please create a .env file in this directory with your OpenAI API key:")
    print(f"   {current_dir / '.env'}")
    print("\nFormat: OPENAI_API_KEY=sk-...")
else:
    # Validate API key format (basic check)
    if not api_key.startswith('sk-'):
        print("⚠️  WARNING: API key format looks incorrect. Should start with 'sk-'")
    else:
        print("✅ OpenAI API key loaded successfully!")
        # Test the API key by making a simple call
        try:
            test_llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0, max_tokens=5)
            test_llm.invoke("Hi")
            print("✅ API key validated successfully!")
        except Exception as e:
            print(f"❌ ERROR: API key validation failed!")
            print(f"   Error: {str(e)}")
            print("\n💡 Please check:")
            print("   1. Your API key is correct (get it from https://platform.openai.com/api-keys)")
            print("   2. You have sufficient credits in your OpenAI account")
            print("   3. The .env file is in the correct location")
            raise

print("\n✅ All imports successful!")
print("📚 Using modern LangChain patterns: create_agent with @tool decorator")
# Out:
# ✅ Loading .env from: /Users/vaisakh/Desktop/Learnings/ai-engineering-bootcamp/rag-powered-q&a-system/.env
# ✅ OpenAI API key loaded successfully!
# ✅ API key validated successfully!
#
# ✅ All imports successful!
# 📚 Using modern LangChain patterns: create_agent with @tool decorator

# %% [markdown]
# Step 1: Loading the documents !!!
# Load the data from the PDF files

# %%
pdf_data_loader = PyPDFLoader("documents/fia_2026_f1_regulations_-_section_a_general_provisions.pdf")

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_core import Document

# Define the folder path where your PDFs are stored
pdf_folder_path = "documents" 

# Initialize an empty list to store all documents
all_documents = []

# Iterate over all files in the directory
for filename in os.listdir(pdf_folder_path):
    if filename.endswith(".pdf"):
        # Construct the full file path
        file_path = os.path.join(pdf_folder_path, filename)
        
        # Create a PyPDFLoader for the specific file
        loader = PyPDFLoader(file_path)
        
        # Load the documents from the PDF and add them to the list
        # .load() returns a list of Document objects (one per page)
        documents = loader.load()
        all_documents.extend(documents)

# You can now work with the combined list of documents
print(f"Successfully loaded {len(all_documents)} pages from all PDFs.")

# Example: Print metadata for the first few documents
for i, doc in enumerate(all_documents[:3]):
    print(f"Document {i+1} source: {doc.metadata['source']}, page: {doc.metadata['page']}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 import os
#       2 from langchain_community.document_loaders import PyPDFLoader
# ----> 3 from langchain.schema import Document
#       5 # Define the folder path where your PDFs are stored
#       6 pdf_folder_path = "documents/"
#
# ModuleNotFoundError: No module named 'langchain.schema'
